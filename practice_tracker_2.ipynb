# %% [markdown]
# # Python Practice Tracker - Set 2
#
# Instructions:
# - Update Status: Not Started / In Progress / Completed
# - Fill Date Completed
# - Write your solution in the code cell below each question

# %% [markdown]
# ## Question 1
#
# **Problem:**
# WAP to check whether a number is positive or negative. If Positive print positive message or else print Negative Number.
#
# **Status:** Not Started
# **Date Completed:**
#
#
# ---

# %%
# Write your solution here
num = int(input("Enter a number: "))
if num > 0:
    print("The number is positive.")
else :
    print("The number is negative.")
# Out:
# The number is positive.

# %% [markdown]
# ## Question 2
#
# **Problem:**
# WAP to check whether a number is even or odd. If even, print message an even or else print message as odd.
#
# **Status:** Not Started
# **Date Completed:**
#
# ---

# %%
# Write your solution here
num = int(input("Enter a number: "))
if num % 2 == 0:
    print("The number is even.")
else :
    print("The number is odd.")
# Out:
# The number is odd.

# %% [markdown]
# ## Question 3
#
# **Problem:**
# Write a program to check whether a given number is greater than 10 or not. if it is greater than 10 print message as greater or else print that number with not a greater than.
#
# **Status:** Not Started
# **Date Completed:**
#
# ---

# %%
# Write your solution here
num = int(input("Enter a number: "))
if num > 10:
    print("The number is greater than 10.")
else :
    print("The number is not greater than 10.")
# Out:
# The number is less than or equal to 10.

# %% [markdown]
# ## Question 4
#
# **Problem:**
# WAP to check whether a given value is present in between 45 to 125. If value is present print the ascii character.
#
# **Status:** Not Started
# **Date Completed:**
#
# ---

# %%
# Write your solution here
num = int(input("Enter a number: "))
if (45 <= num <= 125):
    print(chr(num))
else :
    print("The number is not 45 and 125.")
# Out:
# A

# %% [markdown]
# ## Question 5
#
# **Problem:**
# WAP to check whether the given two input numbers are divisible by 3 and 5. If it is divisible, print “Good Morning”, if it is not print “Good Evening”.
#
# **Status:** Not Started
# **Date Completed:**
#
# ---

# %%
# Write your solution here
num1 = int(input())
num2 = int(input())

if (num1 % 3 == 0 and num1 % 5 == 0) and (num2 % 3 == 0 and num2 % 5 == 0):
    print("Good Morning")
else:
    print("Good Evening")
# Out:
# Good Morning

# %% [markdown]
# ## Question 6
#
# **Problem:**
# WAP to accept two integers and check whether they are equal or not. If equal, multiply to value or quotation value and display it.
#
# **Status:** Not Started
# **Date Completed:**
#
# ---

# %%
# Write your solution here
num1 = int(input())
num2 = int(input())

if (num1 == num2):
    print(num1*num2)
else:
    print('ok')
# Out:
# ok

# %% [markdown]
# ## Question 7
#
# **Problem:**
# WAP to find the largest of two numbers.
#
# **Status:** Not Started
# **Date Completed:**
#
# ---

# %%
# Write your solution here
num1 = int(input())
num2 = int(input())

if (num1 > num2):
    print(f'{num1} is the largest number')
else:
    if num2 > num1:
        print(f"{num2} is the largest number")
    else:
        print("Both numbers are equal")
# Out:
# Both numbers are equal

# %% [markdown]
# ## Question 8
#
# **Problem:**
# WAP to check whether the input number is greater than 10 or not if it is greater than 10 print messages as greater with print that number. if that number is not greater than 10 print that number.
#
# **Status:** Not Started
# **Date Completed:**
#
# ---

# %%
# Write your solution here
num = int(input("Enter a number: "))
if num > 10:
    print(f'{num} is greater than 10.')
else:
    print(f'{num} is not greater than 10.')
# Out:
# 64 is greater than 10.

# %% [markdown]
# ## Question 9
#
# **Problem:**
# WAP to the given number integer, if n is greater than 21,print the absolute difference between n and 21 otherwise print twice the absolute difference.
#
# **Status:** Not Started
# **Date Completed:**
#
# ---

# %%
# Write your solution here
# WAP to the given number integer, if n is greater than 21,print the absolute difference between n and 21 otherwise print twice the absolute difference.

n = int(input("Enter a number: "))
if (n > 21):
    print(n - 21)
else:
    print(2 * (21 - n))
# Out:
# 4

# %% [markdown]
# ## Question 10
#
# **Problem:**
# WAP to find the smallest of two numbers.
#
# **Status:** Not Started
# **Date Completed:**
#
# ---

# %%
# Write your solution here
num1 = int(input())
num2 = int(input())

if (num1 < num2):
    print(f'{num1} is the smallest number')
else:
    if num2 < num1:
        print(f"{num2} is the smallest number")
    else:
        print("Both numbers are equal")
# Out:
# 3 is the smallest number

# %% [markdown]
# ## Question 11
#
# **Problem:**
# WAP to check whether the given number is even or odd. If it is even then make it as an add number, if it is an odd number then make it as even number.
#
# **Status:** Not Started
# **Date Completed:**
#
# ---

# %%
# Write your solution here
num = int(input("Enter a number: "))
if (num % 2 == 0):
    num += 1 
    print(num)
else:
    num += 1 
    print(num)
# Out:
# 7

# %% [markdown]
# ## Question 12
#
# **Problem:**
# WAP to check whether the given number is divisible by 3 or not if yes,print the number or else print the cube of the numbers.
#
# **Status:** Not Started
# **Date Completed:**
#
# ---

# %%
# Write your solution here
num = int(input())
if (num % 3 == 0):
    print(num)
else:
    print(num**3)
# Out:
# 8

# %% [markdown]
# ## Question 13
#
# **Problem:**
# WAP to check whether the given input is divisible by 3 and 5. If yes print the actual number or else print string of that number.
#
# **Status:** Not Started
# **Date Completed:**
#
# ---

# %%
# Write your solution here
num = int(input("Enter a number: "))
if (num % 3 == 0 and num % 5 == 0):
    print(num)
else:
    num = str(num)
    print(str(num))
    print(type(num))
# Out:
# 16
# <class 'str'>

# %% [markdown]
# ## Question 14
#
# **Problem:**
# WAP to check whether the given number lies between 1 to 19, if it is true square that number or else false cube that number  and display the number.
#
# **Status:** Not Started
# **Date Completed:**
#
# ---

# %%
# Write your solution here
num = int(input("Enter a number: "))
if 1 <= num <= 19:
    print(num**2)
else:
    print(num**3)
# Out:
# 9

# %% [markdown]
# ## Question 15
#
# **Problem:**
# WAP to check whether the student has passed or failed. If the student got more than 40 marks, print ‘PASS’ along with those marks, if it is not printed ‘FAIL’ along with those marks.
#
# **Status:** Not Started
# **Date Completed:**
#
# ---

# %%
# Write your solution here
num = int(input("Enter a number: "))
if num >= 40:
    print(f'secured {num} so student passed')
else:
    print(f'secured {num} so student failed')
# Out:
# secured 39 so student failed

# %% [markdown]
# ## Question 16
#
# **Problem:**
# WAP to check whether a given value is even and in range of 47 to 58 and not in 0 or odd. if condition is True, to perform display the ascii character.or else to perform floor division with 5 and display it.
#
# **Status:** Not Started
# **Date Completed:**
#
# ---

# %%
# Write your solution here
num = int(input())
if (num % 2 == 0) and (47 <= num <= 58 ):
    if (num == 0 or num % 2 != 0):
        print(chr(num))
else:
    print(num // 5)
# Out:
# 9

# %% [markdown]
# ## Question 17
#
# **Problem:**
# WAP to check whether a given value is less than 125 and in between 47 to 125 or not. if condition is True, to perform store the given value as key and value as a character into the dict.or else to append the value in list and display it.
#
# **Status:** Not Started
# **Date Completed:**
#
# ---

# %%
# Write your solution here
# WAP to check whether a given value is less than 125 and in between 47 to 125 or not. if condition is True, to perform store the given value as key and value as a character into the dict.or else to append the value in list and display it.
num = int(input("Enter a number: "))
char_dict = {}
char_list = []
if num < 125 and 47 <= num < 125:
    char_dict[num] = chr(num)
else:
    char_list.append(num)
print(char_dict)
print(char_list)
# Out:
# {}
# [46]

# %% [markdown]
# ## Question 18
#
# **Problem:**
# WAP to check whether a given character is in the alphabet or not. if alphabet, display the alphabet with character.or else display the not alphabet with character.
#
# **Status:** Not Started
# **Date Completed:**
#
# ---

# %%
# Write your solution here
char = input("Enter a character: ")
if ('a' <= char <= 'z') or ('A' <= char <= 'Z'):
    print(f'alphabet {char}')
else:
    print(f'not alphabet {char}')
# Out:
# alphabet A

# %% [markdown]
# ## Question 19
#
# **Problem:**
# WAP to check whether a given character is uppercase or other character. if uppercase, display the uppercase with character.or else display the other character with character.
#
# **Status:** Not Started
# **Date Completed:**
#
# ---

# %%
# Write your solution here
char = input("Enter a character: ")
if ('A' <= char <= 'Z'):
    print(f'uppercase {char}')
else:
    print(f'lowercase {char}')
# Out:
# lowercase a

# %% [markdown]
# ## Question 20
#
# **Problem:**
# WAP to check whether a given character is lowercase or other character. if lowercase, display the lowercase with character.or else display the other character with character.
#
# **Status:** Not Started
# **Date Completed:**
#
# ---

# %%
# Write your solution here
char = input("Enter a character: ")
if ('a' <= char <= 'z'):
    print(f'lowercase {char}')
else:
    print(f'other character {char}')
# Out:
# other character @

# %% [markdown]
# ## Question 21
#
# **Problem:**
# WAP to check whether a given character is uppercase or other character. if uppercase, convert to lowercase .or else display the ascii number.
#
# **Status:** Not Started
# **Date Completed:**
#
# ---

# %%
char = input("Enter a character: ")

if 'A' <= char <= 'Z':
    print(chr(ord(char) + 32))
else:
    print(ord(char))
# Out:
# 97

# %% [markdown]
# ## Question 22
#
# **Problem:**
# WAP to check whether the given character is in lowercase or uppercase. If it is in lowercase, convert it into uppercase, or else it is in uppercase and convert it into lowercase. Display the value.
#
# **Status:** Not Started
# **Date Completed:**
#
# ---

# %%
# Write your solution here
char = input("Enter a character: ")
if ('a' <= char <= 'z'):
    print(chr(ord(char)-32))
else:
    print(chr(ord(char)+32))
# Out:
# a

# %% [markdown]
# ## Question 23
#
# **Problem:**
# WAP to check whether the given string of the first character is a special symbol or not. If a special symbol, to extract and display the middle character or else to reverse the string and display the half of the string.
#
# **Status:** Not Started
# **Date Completed:**
#
# ---

# %%
import _typeshed.importlib
s = input("Enter a string: ")

first = s[0]

if not ('a' <= first <= 'z' or 'A' <= first <= 'Z' or '0' <= first <= '9'):
    mid = len(s) // 2
    print(s[mid])
else:
    rev = s[::-1]
    print(rev[:len(s)//2])
# Out:
# n

# %% [markdown]
# ## Question 24
#
# **Problem:**
# WAP to check whether the input character is a vowel or not. If it is vowel print ‘VOWEL’ along with that character, if it is not just print ‘CONSONANT’.
#
# **Status:** Not Started
# **Date Completed:**
#
# ---

# %%
# Write your solution here
char = input('enter a number')
if (char in 'aeiouAEIOU'):
    print(f'VOWEL {char}')
else:
    print('CONSTANT')
# Out:
# CONSTANT

# %% [markdown]
# ## Question 25
#
# **Problem:**
# WAP to check whether a given character is a vowel or consonant. if vowel,to print the next character of a given character or else print previous characters.
#
# **Status:** Not Started
# **Date Completed:**
#
# ---

# %%
# Write your solution here
char = input()
if (char in 'aeiouAEIOU'):
    print(chr(ord(char)+1))
else:
    print(chr(ord(char)-1))
# Out:
# b

# %% [markdown]
# ## Question 26
#
# **Problem:**
# WAP to check whether a given string of first character is alphabet or not if the alphabet prints, reverse the string or else print the middle character.
#
# **Status:** Not Started
# **Date Completed:**
#
# ---

# %%
# Write your solution here
s = input("Enter a string: ")

first = s[0]
if ('a' <= first <= 'z' or 'A' <= first <= 'Z'):
    print(s[::-1])
else:
    mid = len(s) // 2
    print(s[mid])
# Out:
# n

# %% [markdown]
# ## Question 27
#
# **Problem:**
# WAP to check whether the given input character is uppercase or lowercase. If the input character is upper case convert into lower case and vice versa.
#
# **Status:** Not Started
# **Date Completed:**
#
# ---

# %%
# Write your solution here
char = input("Enter a character: ")
if ('A' <= char <= 'Z'):
    print(chr(ord(char)+32))
else:
    print(chr(ord(char)-32))

# %% [markdown]
# ## Question 28
#
# **Problem:**
# WAP to check whether a given string is less than 3 characters, to print the entire string otherwise to print after third positions to the remaining string.
#
# **Status:** Not Started
# **Date Completed:**
#
# ---

# %%
# Write your solution here
char = input()
len_char = len(char)
if (len(char) == 3):
    print(char)
else:
    print(char[3:])
# Out:
# l

# %% [markdown]
# ## Question 29
#
# **Problem:**
# WAP to check whether a given length of the string is even or not. if even, to append the new string called "bye" or else print the first and last characters.
#
# **Status:** Not Started
# **Date Completed:**
#
# ---

# %%
# Write your solution here
char =  input()
len_char = len(char)
if (len_char % 2 == 0):
    print(char +' ' + 'bye')
else:
    print(char[0],char[-1])
# Out:
# anil bye

# %% [markdown]
# ## Question 30
#
# **Problem:**
# WAP to check whether a given length of the string is odd or not. if odd, to append the new string("Haii") from the starting of the given string, or else to avoid the starting character and ending character of the given string and to display the remaining characters.
#
# **Status:** Not Started
# **Date Completed:**
#
# ---

# %%
# Write your solution here
char = input('enter a character')
len_char = len(char)
if (len_char % 2 != 0):
    print('hai' +''+char)
else:
    print(char[1:-1])
# Out:
# ni

# %% [markdown]
# ## Question 31
#
# **Problem:**
# WAP to check whether the last of the given string is a special character or not, if the special character prints reverse the string except the last character or else to check if the length of the string is odd or not, if odd to extract the middle character to the end of the string.
#
# **Status:** Not Started
# **Date Completed:**
#
# ---

# %%
s = input("Enter a string: ")

first = s[-1]

if not ('a' <= first <= 'z' or 'A' <= first <= 'Z' or '0' <= first <= '9'):
    print(s[:-1][::-1])
else:
    if (len(s) % 2 != 0):
        mid = len(s) // 2
        print(s[mid:])
    else:
        print('even')
# Out:
# lina

# %% [markdown]
# ## Question 32
#
# **Problem:**
# WAP to check whether a given year is a leap year or not. if leap year, print leap year or else not a leap year.
#
# **Status:** Not Started
# **Date Completed:**
#
# ---

# %%
# Write your solution here
# import calendar
year = int(input("Enter a year: "))

if (year % 400 == 0) or (year % 4 == 0 and year % 100 != 0):
    print("Leap Year")
else:
    print("Not a Leap Year")
# Out:
# Leap Year

# %% [markdown]
# ## Question 33
#
# **Problem:**
# WAP to find out the greatest of two numbers and display the greatest number.if the greatest number, display the greatest message with value.
#
# **Status:** Not Started
# **Date Completed:**
#
# ---

# %%
# Write your solution here
num1 = int(input())
num2 = int(input())
if (num1 > num2):
    print(f'greatest {num1}')
else:
    if (num1 < num2):
        print(f'greatest {num2}')
# Out:
# greatest 3

# %% [markdown]
# ## Question 34
#
# **Problem:**
# WAP to check whether the given value is present inside the given collection or not.if value is present, display the value is available or else the value is not present.
#
# **Status:** Not Started
# **Date Completed:**
#
# ---

# %%
# Write your solution here
# WAP to check whether the given value is present inside the given collection or not.if value is present, display the value is available or else the value is not present.

# The given collection
my_collection = [10, 20, 30, 40, 50]

# Ask the user for input and convert it to an integer
value_to_check = int(input("Enter a value to check: "))

# Check if the user's value is present in the collection
if value_to_check in my_collection:
    print("the value is available")
else:
    print("the value is not present")
# Out:
# the value is available

# %% [markdown]
# ## Question 35
#
# **Problem:**
# WAP whether a given string, if string length is more than 2, then it displays a new string with the first and last characters switched, otherwise the display the 3 copies of given string.
#
# **Status:** Not Started
# **Date Completed:**
#
# ---

# %%
# Write your solution here
char = input()
if len(char) > 2:
    new_word = char[-1] + char[1:-1] + char[0]
    print(new_word)
else:
    print((char + ",") * 3)
# Out:
# ai,ai,ai,

# %% [markdown]
# ## Question 36
#
# **Problem:**
# WAP to check whether a given value is a list and first and last values should be integer,if condition is satisfied first value is true division by 3 and perform the bitwise not for last value and those result values are stored in same positions in list or else, to perform length of the collection power 2 and display it.
#
# **Status:** Not Started
# **Date Completed:**
#
# ---

# %%
# Write your solution here
value = [9,56,89,26,6,5]

if type(value) == list and type(value[0]) == int and type(value[-1]) == int:
    value[0] = value[0] / 3
    value[-1] = ~value[-1]
    print(value)
else:
    print(len(value) ** 2)
# Out:
# 36

# %% [markdown]
# ## Question 37
#
# **Problem:**
# WAP to check whether a given value is a string or not and length of the value should be more than 7, if condition is satisfied to append the new string in the middle of the given string or else to perform the replications with 3 and display the result.
#
# **Status:** Not Started
# **Date Completed:**
#
# ---

# %%
# Write your solution here

# %% [markdown]
# ## Question 38
#
# **Problem:**
# WAP to check if the given string of first and second character should be sequence or not. if the sequence prints the first,second and last two characters, or else the first half string is reversed and the remaining half string should be normal and display it.
#
# **Status:** Not Started
# **Date Completed:**
#
# ---

# %%
# Write your solution here

# %% [markdown]
# ## Question 39
#
# **Problem:**
# WAP to check whether a given value is present inside the collection or not. If present, print the value or else print value is not found.
#
# **Status:** Not Started
# **Date Completed:**
#
# ---

# %%
# Write your solution here
my_collection = [10, 20, 30, 40, 50]

# Ask the user for input and convert it to an integer
value_to_check = int(input("Enter a value to check: "))

# Check if the user's value is present in the collection
if value_to_check in my_collection:
    print("value found")
    print(value_to_check)
else:
    print("the value is not found")
# Out:
# the value is not found

# %% [markdown]
# ## Question 40
#
# **Problem:**
# WAP to check whether a given key is present in the dict or not. if key is present: display the value or else add key and new value inside the dict.
#
# **Status:** Not Started
# **Date Completed:**
#
# ---

# %%
# Write your solution here
d = {"a":10,"b":20,"c":30}
key = input("Enter key: ")

if key in d:
    print(d[key])
else:
    value = input("Enter value: ")
    d[key] = value
    print(d)
# Out:
# {'a': 10, 'b': 20, 'c': 30, 'z': 'ax'}

# %% [markdown]
# ## Question 41
#
# **Problem:**
# WAP to check whether a given collection is set or not.if set, append the new value, or else eliminate the duplicate values in collection. final results should be set type.
#
# **Status:** Not Started
# **Date Completed:**
#
# ---

# %%
# Write your solution here
collection = eval(input('enter a collection'))
if type(collection) == set:
    collection.add('namaste') # To append a new value to a set, we must use the .add() method (sets don't have .append())
else:
    collection = set(collection)# Eliminate duplicate values by converting the collection into a set because set wont allow duplicates
print(collection)
print(type(collection))
# Out:
# {1, 5, 22, 23}
# <class 'set'>

# %% [markdown]
# ## Question 42
#
# **Problem:**
# WAP to read the age of a candidate and determine whether it is eligible for his/her own vote or not.it eligible print age and eligible messages or else print not eligible.
#
# **Status:** Not Started
# **Date Completed:**
#
# ---

# %%
# Write your solution here
age = int(input('enter a age'))
if age >= 18:
    print(f'{age} eligible')
else:
    print('not eligible')
# Out:
# 18 eligible

# %% [markdown]
# ## Question 43
#
# **Problem:**
# WAP to check whether the given string is palindrome or not if it is a palindrome string palindrome along with the string if it is not a palindrome print not palindrome
#
# **Status:** Not Started
# **Date Completed:**
#
# ---

# %%
# Write your solution here
palindrome = input('enter a string')
stright = palindrome[0:]
reverse = palindrome[::-1]
if stright == reverse:
    print(f'its a palindrome {palindrome}')
else:
    print('not a palindrome')
# Out:
# its a palindrome mom

# %% [markdown]
# ## Question 44
#
# **Problem:**
# WAP to check whether a given number is palindrome or not. If palindrome, display the given value as a palindrome or else not a palindrome.
#
# **Status:** Not Started
# **Date Completed:**
#
# ---

# %%
# Write your solution here
palindrome = int(input('enter a string'))
pali = str(palindrome)
stright = pali[0:]
reverse = pali[::-1]
if stright == reverse:
    print(f'its a palindrome {palindrome}')
else:
    print('not a palindrome')
# Out:
# not a palindrome

# %% [markdown]
# ## Question 45
#
# **Problem:**
# WAP to check length of both string collections equal or not if both are equal print the concat the two strings and display, or else if any one of the collection not equal print both the collections with lengths
#
# **Status:** Not Started
# **Date Completed:**
#
# ---

# %%
# Write your solution here
str1 = input()
str2 = input()

if len(str1) == len(str2):
    print(str1 + str2)
else:
    print(str1, len(str1))
    print(str2, len(str2))
# Out:
# anilkali

# %% [markdown]
# ## Question 46
#
# **Problem:**
# WAP to check whether both given values point to the same memory location or not. if it is true print the middle item of the second collection, or else if it is false print the first item and last item of the first collection along with the memory address.
#
# **Status:** Not Started
# **Date Completed:**
#
# ---

# %%
# Write your solution here
n1 = eval(input())
n2 = eval(input())

if id(n1) == id(n2):
    mid = len(n2) // 2
    print(n2[mid])
else:
    print(n1[0], n1[-1], id(n1))
# Out:
# 2 6 3275652582528

# %% [markdown]
# ## Question 47
#
# **Problem:**
# WAP to  check whether a given string collection is more than ten, and the first + last character of the ascii values should be divisible by 5, if condition is satisfied print first,middle,last characters ASCII values or else print the string three times.
#
# **Status:** Not Started
# **Date Completed:**
#
# ---

# %%
# Write your solution here

# %% [markdown]
# ## Question 48
#
# **Problem:**
# WAP to check whether the middle of the item present in the list is string data type or not if it is string print that list or else if it is not string  then print that middle item.
#
# **Status:** Not Started
# **Date Completed:**
#
# ---

# %%
# Write your solution here

# %% [markdown]
# ## Question 49
#
# **Problem:**
# WAP Given a string, return a new string where the first and last characters have been exchanged.
#
# **Status:** Not Started
# **Date Completed:**
#
# ---

# %%
# Write your solution here

# %% [markdown]
# ## Question 50
#
# **Problem:**
# Write a program to find out such numbers which are divisible by 7 but are not a multiple of 5. Both the conditional are satisfied and print actual value. if one condition is not satisfied actual number is multiply by 4 and print result
#
# **Status:** Not Started
# **Date Completed:**
#
# ---

# %%
# Write your solution here

# %% [markdown]
# ## Question 51
#
# **Problem:**
# WAP to check whether two values are pointing to the same memory address or not. If the same memory displays the address or else displays the two values addresses.
#
# **Status:** Not Started
# **Date Completed:**
#
# ---

# %%
# Write your solution here

# %% [markdown]
# ## Question 52
#
# **Problem:**
# WAP to check whether a given input character is a special symbol or not if it is a special symbol then print that character three times and tell print that character 5 times.
#
# **Status:** Not Started
# **Date Completed:**
#
# ---

# %%
# Write your solution here

# %% [markdown]
# ## Question 53
#
# **Problem:**
# WAP to check length of both string collections equal or not if it is equal print the connection of any one of the collections if it is not equal print both the collection.
#
# **Status:** Not Started
# **Date Completed:**
#
# ---

# %%
# Write your solution here

# %% [markdown]
# ## Question 54
#
# **Problem:**
# WAP To check whether both input variables point to the same memory location or not if it is true print the last item of the second collection, if it is false print the first item of the first collection along with the memory address.
#
# **Status:** Not Started
# **Date Completed:**
#
# ---

# %%
# Write your solution here

# %% [markdown]
# ## Question 55
#
# **Problem:**
# WAP to print the string collection five times when the length of the string collection should be more than 3 and the middle character of the string should be vowel and the first character ASCII value should be even, to print the previous character of middle character, or else if ASCII value is odd then print the string three times as print that string.
#
# **Status:** Not Started
# **Date Completed:**
#
# ---

# %%
# Write your solution here

# %% [markdown]
# ## Question 56
#
# **Problem:**
# Ravi would like to buy a new cello or red pen. The cost of the pen should be 10. If the pen is available in the shop, he will buy the pen. If it is not there he will come out of the shop.
#
# **Status:** Not Started
# **Date Completed:**
#
# ---

# %%
# Write your solution here

# %% [markdown]
# ## Question 57
#
# **Problem:**
# WAP to perform addition and subtraction operation by using list collection if the first and middle data items number are even performing addition operation, or else performing subtraction.
#
# **Status:** Not Started
# **Date Completed:**
#
# ---

# %%
# Write your solution here

# %% [markdown]
# ## Question 58
#
# **Problem:**
# WAP to check whether the first item of these two lists is either integer or not. If it is an integer, concatenate these two lists or else print the memory address of these two lists.
#
# **Status:** Not Started
# **Date Completed:**
#
# ---

# %%
# Write your solution here
