# %%
# WAP to check whether a given value is less than 125 and in between 47 to 125 or not. if condition is True, to perform store the given value as key and value as a character into the dict.or else to append the value in list and display it.
num = int(input("Enter a number: "))
char_dict = {}
char_list = []
if num < 125 and 47 <= num < 125:
    char_dict[num] = chr(num)
else:
    char_list.append(num)
print(char_dict)
print(char_list)

# %%
# WAP to take the input from the user as a number and check whether it is a number or not. if yes. take the number and add some value and print it.
# Write your solution here
num = input("Please type in a number: ")
if ('0' <= num <= '9'):
    print(int(num)+3)
# Out:
# 69

# %%
# WAP to check whether the given value's last digit is greater than 5 or not.if greater, to perform the bitwise right shift operator (skipping value is 2)
# Write your solution here
num = int(input('enter a number: '))
# get last digit and check if greater than 5
if (num % 10) > 5:
    # perform bitwise right shift by 2 (skip value is 2)
    result = num >> 2
    print(result)

# %%
# Write your solution here
# WAP to check whether a given value is less than 125 and greater than 60 or not. If the condition is satisfied, take the name and extract the middle character and display it.

num = int(input('enter a number: '))
if 60 < num < 125:
    name =  input('enter a number: ')
    name1 = name[len(name) // 2]
    print(name1)

# %%
# WAP to check whether a character is in the alphabet or not. If the alphabet, store the value inside the dict(key as a character and value as an ascii value).
ch = input("Enter a character: ")
if ('A' <= ch <= 'Z' or 'a' <= ch <= 'z'):
    dict = {ch: ord(ch)}
    print(dict)

# %%
# Write your solution here
# WAP to check whether a character is in the uppercase or not. If the uppercase, convert to lowercase and store the value inside the dict(character as a key and ascii value as a value).
ch = input("Enter a character: ")
if ('A' <= ch <= 'Z'):
    ch_low = ch.lower()
    ch_low_dict = {ch:ord(ch)}
    print(ch_low_dict)

# %%
# Write your solution here
# WAP to check whether a character is in the vowel or not. If the vowel,print the next character.

char = input()
if (char in 'aeiouAEIOU'):
    print(chr(ord(char)+1))
    # result = ord(char)
    # result2 = result + 1
    # result3 = chr(result2)
    # print(result3)
